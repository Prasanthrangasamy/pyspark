# %%
# %sql
CREATE DATABASE learn_data.data

# %%
# %sql
CREATE VOLUME learn_data.data.files

# %%
df=spark.read.csv('/Volumes/learn_data/data/files/orders/orders.csv')

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.csv('/Volumes/learn_data/data/files/orders/orders.csv',header=True)

# %%
display(df)
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.csv('/Volumes/learn_data/data/files/orders/orders.csv',header=True, inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- quantity: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- delivery_date: date (nullable = true)

# %%
df=spark.read.json('/Volumes/learn_data/data/files/orders/orders.json', multiLine=True)

# %%
display(df)
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.format('json').options(multiLine=True, inferSchema=True).load('/Volumes/learn_data/data/files/orders/orders.json')

# %%
display(df)
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.read.format('parquet').options(header=True, inferSchema=True).load('/Volumes/learn_data/data/files/orders/orders.parquet')

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
